# %% [markdown]
# * toplam fiyat
# * rastgele tatlı (isteğe bağlı)
# * indirim günü
# * index- serra
# * dosyaya yazdırma
# * ödeme(tür) - kredi kartı-nakit => para yetmiyorsa 1 gün çalışsın
# * garson, aşçı
# * gelir gider

# %%
print("Restorana hosgeldiniz")
import datetime
import pandas as pd
menu = pd.DataFrame({"Yemekler": ["Pizza","Makarna","Çorba","Pilav"],
                     "Çeşit : 1" : ["Margarita","Spagetti","Mercimek","Pirinç"],
                     "Çeşit : 2" : ["Etli", "Kelebek","Yayla","Bulgur"],
                     "Çeşit : 3" : ["Veggie","Boncuk","Tarhana","Nohutlu"],
                     "Fiyat" : [25,15,10,20]})
print(menu)
import pandas as pd
menu_icecek = pd.DataFrame({"İçecekler" : ["Kola","Fanta","IceTea","Gazoz","Ayran"],
                                           "Fiyat" : [5,5,3,4,2]})
print(menu_icecek)
toplam_fiyat = 0

adS = input("Lütfen isim-soyisim giriniz")
Budget = int(input("Lütfen bütçenizi giriniz: "))
kisi = int(input("Lütfen kaç kişinin sipariş vereceğini giriniz: "))
class Menu:
  def __init__(self,isim,fiyat ):
    self.isim = isim
    self.fiyat = fiyat
  
 

  def odeme(self):
   tur = input("Lütfen ödeme türünüzü seçiniz. Kart mı? Nakit mi?")
   if tur == "Nakit":
    print("Ödemeniz nakit alınacaktır.")
    if Budget-{self.fiyat} <0:
        print("Üzgünüm, bütçeniz siparişlerinizi karşılamıyor.Lütfen siparişlerinizi ya da ödeme yönteminizi değiştiriniz")
    elif tur == "Kart":
      print("Ödemeniz karttan alınacaktır.")


class Pizza(Menu):
  def __init__(self, isim, fiyat, icindekiler,boy,kenar,sos):
      super().__init__(isim, fiyat)
      self.icindekiler = icindekiler
      self.boy = boy
      self.kenar = kenar
      self.sos = sos
  def SiparisGoster(self):
   print(f"AD-Soyad:{adS}, Sipariş: {self.isim}, Fiyat:{self.fiyat}, Ödeme:  İçindekiler: {self.icindekiler}, Sosu: {self.sos}, Kalan Bütçe: {Budget-self.fiyat}")


  def siparis(self):
    s = input("siparişinizde değişiklik yapmak istiyor musunuz: ")
    if s == "hayir":
        e = input(("Eklemek ıstedıgınız urun: "))
        c = input(("Cıkartmak ıstedıgınız urun: "))
        if e == "yok":
           pass
        else:       
            self.icindekiler.append(e)
        if c == "yok":
            pass
        else: 
            self.icindekiler.remove(c)
    else:
        print("siparisiniz kaydedildi")
  
  
class Çorba(Menu):
    def __init__(self, isim, fiyat):
      super().__init__(isim, fiyat)
    def SiparisGoster(self):
      print(f"AD-Soyad:{adS}, Sipariş: {self.isim}, Fiyat:{self.fiyat}, Baharat : {baharat} Kalan Bütçe: {Budget-self.fiyat}")

class Makarna(Menu):
    def __init__(self, isim, fiyat):
      super().__init__(isim, fiyat)

    def SiparisGoster(self):
        print(f"AD-Soyad:{adS}, Sipariş: {self.isim}, Sos: {sos} Fiyat:{self.fiyat}, Kalan Bütçe: {Budget-self.fiyat}")           

class Pilav(Menu):
    def __init__(self, isim, fiyat,cesit):
      super().__init__(isim, fiyat )
      self.cesit = cesit
    def SiparisGoster(self):
        print(f"AD-Soyad:{adS}, Sipariş: {self.isim}, Cesit: {self.cesit} Fiyat:{self.fiyat}, Kalan Bütçe: {Budget-self.fiyat}")

class Icecek(Menu):
    def _init_(self, isim, fiyat):
      super()._init_(isim, fiyat )
    def SiparisGoster(self):
      print(f"AD-Soyad:{adS}, Sipariş: {self.isim}, Boyut: {b} Fiyat:{self.fiyat}, Kalan Bütçe: {Budget-self.fiyat}")
     



l1 = ["mozarella", "domates"]
l2 = ["mozarella", "domates", "biber", "patlican"]
l3 = ["mozarella", "domates", "sucuk"]
pmenusozluk = {"01" :['Margarıta', 10, l1], "02" : ["VeggiePizza" , 12,l2], "03" :[ "EtliPizza" , 15, l3],
"11" :['Mercimek', 10], "12" : ["Yayla Çorbası" , 12], "13" :[ "Tarhana Çorbası" , 15],
"21" :['Spagetti', 10], "22" : ["Kelebek" , 12], "23" :[ "Boncuk makarna" , 15],
"9" :['Nohutlu Pilav', 40], "10" : ["Tavuklu Pilav" , 40], "11" :[ "Bulgur Pilavı" , 40],
"12" :['Coca Cola', 20], "13" : ["Ayran" , 10], "14" :[ "Ice Tea" , 40], "15" : ["Fanta" , 15], "16" : ["Meyve Suyu", 10]}
while True:
    

        urun = input("Sipariş etmek istediğiniz yemeği girin: (Pizza,Makarna,Çorba,Pilav,İçecek) " )
        if urun == "Pizza":
           
            sayi = int(input("Lütfen kac adet pizza siparis edeceginizi giriniz: "))
            
            for i in range(sayi):
              siparis = input("Lutfen {} numarali sıparısinizi gırınız" .format(i+1) )
              boy =input("Lütfen boyutunu giriniz:")
              kenar = input("Lütfen kenarı giriniz:")
              sos = input("Lutfen sos giriniz: ")
              if siparis == '01':
                pizza = Pizza(isim= pmenusozluk[(siparis)][0], fiyat = pmenusozluk[(siparis)][1] , icindekiler=pmenusozluk[(siparis)][2] , boy = boy, kenar = kenar, sos = sos)
                print("Icındekıler: ", l1)
                pizza.siparis()
                pizza.SiparisGoster()


              elif siparis == '02':
                pizza = Pizza(isim= pmenusozluk[(siparis)][0], fiyat = pmenusozluk[(siparis)][1] , icindekiler=pmenusozluk[(siparis)][2] , boy = boy, kenar = kenar, sos = sos)
                print("Icındekıler: ", l2)
                pizza.siparis()
                
                pizza.SiparisGoster()
            
              elif siparis == '03':
                pizza = Pizza(isim= pmenusozluk[(siparis)][0], fiyat = pmenusozluk[(siparis)][1] , icindekiler=pmenusozluk[(siparis)][2] , boy = boy, kenar = kenar, sos = sos)
                print("Icındekıler: ", l3)
                pizza.siparis()  
            
                pizza.SiparisGoster()


        elif urun == "Çorba":
          print("06.00-12.00 arasında çorba servisimiz vardır, maalesef bu saatler dışında servis yoktur")
          try:
            now = datetime.datetime.now() 
             
            if 6 <= now.hour < 12:
               print(f"Saat : {now.hour}.00 , {urun} serivisi vardır.")
               x =  int(input("Lütfen kac adet çorba siparis edeceginizi giriniz: "))
               
               for c in range(x):
                alinan = input(f"Lutfen {c+1} numarali sıparısinizi gırınız" )
                by = int(input("Baharat istiyorsanız lütfen 1'e , baharat istemiyorsanız lütfen 0'a basın."))
               if by == 1:
                  baharat = input("Lütfen baharatı giriniz:")
                  print(f"{baharat} ekleniyor")
               elif by == 0:
                  pass
               corba =Çorba(isim=pmenusozluk[(alinan)][0], fiyat= pmenusozluk[alinan][1])
               corba.SiparisGoster()
            else:
               print(f"Saat : {now.hour}.{now.minute}, {urun} servisi yoktur.")
               pass
          except Exception as e:
            print(f"{urun} servisinde bir hata oluştu ve sebebi:{e}")
              

        elif urun == "Makarna":
          
          adet =  int(input("Lütfen kac adet makarna siparis edeceginizi giriniz: "))
          
          for b in range(adet):
            istenen = input("Lutfen {} numarali sıparısinizi gırınız" .format(b+1) )
            sos = input("Lütfen sos giriniz:")
            print(f"{sos} ekleniyor")
            makarna =Makarna(isim=pmenusozluk[(istenen)][0], fiyat= pmenusozluk[istenen][1])
            makarna.SiparisGoster()
            

        elif urun == "Pilav":
            s =  int(input("Lütfen kac adet pilav siparis edeceginizi giriniz: "))
           
            for a in range(s):
              ilgili = input("Lutfen {} numarali sıparısinizi gırınız" .format(a+1) )
              pilav =Pilav(isim=pmenusozluk[(ilgili)][0], fiyat= pmenusozluk[ilgili][1], cesit =pmenusozluk[(ilgili)][0] )
              pilav.SiparisGoster()
            
        elif urun == "İcecek":
         ic =  int(input("Lütfen kac adet içecek siparis edeceginizi giriniz: "))
         print(icecek)
         for w in range(ic):
            ilgili = input("Lutfen {} numarali sıparısinizi gırınız" .format(w+1) )
            b = input("Lütfen içeceğinizin boyutunu giriniz: ")
            
            icecek = Icecek(isim=pmenusozluk[(ilgili)][0], fiyat= pmenusozluk[ilgili][1])
            icecek.odeme()
            icecek.SiparisGoster()
            
                
        else:
            print("girdiğiniz ürün yoktur, lütfen tekrar seçiniz")
            continue
        
        toplam_fiyat += pmenusozluk[siparis][1]
        urun_ekleme = input("başka bir yemek eklemek istiyor musunuz: (Evet-Hayır)")
        if urun_ekleme == "Evet":
            continue
        else:
            pass
        kontrol = input("Yaptığınız işlemler doğru mu? (Evet-Hayır)")
        if kontrol == "Evet":
            break

''' def odeme(self):
   tur = input("Lütfen ödeme türünüzü seçiniz. Kart mı? Nakit mi?")
   if tur == "Nakit":
    print("Ödemeniz nakit alınacaktır.")
    if Budget-{} <0:
        print("Üzgünüm, bütçeniz siparişlerinizi karşılamıyor.Lütfen siparişlerinizi ya da ödeme yönteminizi değiştiriniz")
    elif tur == "Kart":
      print("Ödemeniz karttan alınacaktır.")'''
# Out:
# Restorana hosgeldiniz
#   Yemekler  Çeşit : 1 Çeşit : 2 Çeşit : 3  Fiyat
# 0    Pizza  Margarita      Etli    Veggie     25
# 1  Makarna   Spagetti   Kelebek    Boncuk     15
# 2    Çorba   Mercimek     Yayla   Tarhana     10
# 3    Pilav     Pirinç    Bulgur   Nohutlu     20
#   İçecekler  Fiyat
# 0      Kola      5
# 1     Fanta      5
# 2    IceTea      3
# 3     Gazoz      4
# 4     Ayran      2
# Saat : 23.00 , Çorba serivisi vardır.
# Çorba servisinde bir hata oluştu ve sebebi:invalid literal for int() with base 10: 'yok'
# ' def odeme(self):\n   tur = input("Lütfen ödeme türünüzü seçiniz. Kart mı? Nakit mi?")\n   if tur == "Nakit":\n    print("Ödemeniz nakit alınacaktır.")\n    if Budget-{} <0:\n        print("Üzgünüm, bütçeniz siparişlerinizi karşılamıyor.Lütfen siparişlerinizi ya da ödeme yönteminizi değiştiriniz")\n    elif tur == "Kart":\n      print("Ödemeniz karttan alınacaktır.")'

# %%
import pandas as pd
menu = pd.DataFrame({"Yemekler": ["Pizza","Makarna","Çorba","Pilav"],
                     "Çeşit : 1" : ["Margarita","Spagetti","Mercimek","Pirinç"],
                     "Çeşit : 2" : ["Etli ", "Kelebek ","Yayla","Bulgur"],
                     "Çeşit : 3" : ["Veggie ","Boncuk ","Tarhana","Nohutlu "],
                     "Fiyat" : [25,15,10,20]})
menu
# Out:
#   Yemekler  Çeşit : 1 Çeşit : 2 Çeşit : 3  Fiyat
# 0    Pizza  Margarita     Etli    Veggie      25
# 1  Makarna   Spagetti  Kelebek    Boncuk      15
# 2    Çorba   Mercimek     Yayla   Tarhana     10
# 3    Pilav     Pirinç    Bulgur  Nohutlu      20

# %%
import pandas as pd
menu = pd.DataFrame({"Yemekler": ["Pizza","Makarna","Çorba","Pilav"],
                     "Çeşit : 1" : ["Margarita","Spagetti","Mercimek","Pirinç"],
                     "Çeşit : 2" : ["Etli ", "Kelebek ","Yayla","Bulgur"],
                     "Çeşit : 3" : ["Veggie","Boncuk ","Tarhana","Nohutlu "],
                     "Fiyat" : [25,15,10,20]})
print(menu)

while True:

    yemek = input("Sipariş etmek istediğiniz yemeği girin: (Pizza,Makarna,Çorba,Pilav) " )
    if yemek == "Pizza":
        print(f"Seçilen yemek: {yemek}")
        cesit = input("Seçmek istediğiniz pizza çeşidini giriniz : (Margarita,Etli,Veggie)")
        if cesit == "Margarita":
            secilen_cesit = menu.loc[menu['Yemekler'] == 'Pizza', 'Çeşit : 1']
            print(f"Seçilen çeşit: {secilen_cesit.values[0]}")
        elif cesit == "Spagetti":
            secilen_cesit = menu.loc[menu['Yemekler'] == 'Pizza', 'Çeşit : 2']
            print(f"Seçilen çeşit: {secilen_cesit.values[0]}")
        elif cesit == "Veggie":
            secilen_cesit = menu.loc[menu['Yemekler'] == 'Pizza', 'Çeşit : 3']
            print(f"Seçilen çeşit: {secilen_cesit.values[0]}")
        else: 
            print("girdiğiniz çeşit pizza yoktur, lütfen tekrar seçiniz")
            
        
        
    elif yemek == "Makarna":
        cesit = input("Seçmek istediğiniz makarna çeşidini giriniz : (Spagetti,Kelebek,Boncuk)")
        if cesit == "Spagetti":
            secilen_cesit = menu.loc[menu['Yemekler'] == 'Makarna', 'Çeşit : 1']
            print(f"Seçilen çeşit: {secilen_cesit.values[0]}")
        elif cesit == "Kelebek":
            secilen_cesit = menu.loc[menu['Yemekler'] == 'Makarna', 'Çeşit : 2']
            print(f"Seçilen çeşit: {secilen_cesit.values[0]}")
        elif cesit == "Boncuk":
            secilen_cesit = menu.loc[menu['Yemekler'] == 'Makarna', 'Çeşit : 3']
            print(f"Seçilen çeşit: {secilen_cesit.values[0]}")
        else: 
            print("girdiğiniz çeşit makarna yoktur, lütfen tekrar seçiniz")
           

    elif yemek == "Çorba":
        cesit = input("Seçmek istediğiniz çorba çeşidini giriniz : (Mercimek,Yayla,Tarhana)")
        if cesit == "Mercimek":
            secilen_cesit = menu.loc[menu['Yemekler'] == 'Çorba', 'Çeşit : 1']
            print(f"Seçilen çeşit: {secilen_cesit.values[0]}")
        elif cesit == "Yayla":
            secilen_cesit = menu.loc[menu['Yemekler'] == 'Çorba', 'Çeşit : 2']
            print(f"Seçilen çeşit: {secilen_cesit.values[0]}")
        elif cesit == "Tarhana":
            secilen_cesit = menu.loc[menu['Yemekler'] == 'Çorba', 'Çeşit : 3']
            print(f"Seçilen çeşit: {secilen_cesit.values[0]}")
        else: 
            print("girdiğiniz çorba yoktur, lütfen tekrar seçiniz")
           

    elif yemek == "Pilav":
        cesit = input("Seçmek istediğiniz pilav çeşidini giriniz : (Pirinç,Bulgur,Nohutlu)")
        if cesit == "Margarita":
            secilen_cesit = menu.loc[menu['Yemekler'] == 'Pilav', 'Çeşit : 1']
            print(f"Seçilen çeşit: {secilen_cesit.values[0]}")
        elif cesit == "Spagetti":
            secilen_cesit = menu.loc[menu['Yemekler'] == 'Pilav', 'Çeşit : 2']
            print(f"Seçilen çeşit: {secilen_cesit.values[0]}")
        elif cesit == "Veggie":
            secilen_cesit = menu.loc[menu['Yemekler'] == 'Pilav', 'Çeşit : 3']
            print(f"Seçilen çeşit: {secilen_cesit.values[0]}")
        else: 
            print("girdiğiniz çeşit pilav yoktur, lütfen tekrar seçiniz")
            
    else:
        print("girdiğiniz çeşit yemek yoktur, lütfen tekrar seçiniz")
        continue
    kontrol = input("Yaptığınız işlemler doğru mu? (Evet-Hayır)")
    if kontrol == "Evet":
        break
# Out:
#   Yemekler  Çeşit : 1 Çeşit : 2 Çeşit : 3  Fiyat
# 0    Pizza  Margarita     Etli     Veggie     25
# 1  Makarna   Spagetti  Kelebek    Boncuk      15
# 2    Çorba   Mercimek     Yayla   Tarhana     10
# 3    Pilav     Pirinç    Bulgur  Nohutlu      20
# girdiğiniz çeşit yemek yoktur, lütfen tekrar seçiniz
# girdiğiniz çeşit yemek yoktur, lütfen tekrar seçiniz
# girdiğiniz çeşit yemek yoktur, lütfen tekrar seçiniz
# girdiğiniz çeşit yemek yoktur, lütfen tekrar seçiniz
# girdiğiniz çeşit yemek yoktur, lütfen tekrar seçiniz
# girdiğiniz çeşit yemek yoktur, lütfen tekrar seçiniz
# girdiğiniz çeşit yemek yoktur, lütfen tekrar seçiniz
# girdiğiniz çeşit yemek yoktur, lütfen tekrar seçiniz
# girdiğiniz çeşit yemek yoktur, lütfen tekrar seçiniz
# girdiğiniz çeşit yemek yoktur, lütfen tekrar seçiniz
# girdiğiniz çeşit yemek yoktur, lütfen tekrar seçiniz
# girdiğiniz çeşit yemek yoktur, lütfen tekrar seçiniz
# girdiğiniz çeşit yemek yoktur, lütfen tekrar seçiniz
# ...
